# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
df = pd.read_csv('/Users/asanchez/Downloads/Unemployment.csv')
df
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# ...

# %%
df.plot(kind= 'scatter',
       x = 'HARDSHIP INDEX',
       y= 'PER CAPITA INCOME ',
       color= 'green',
       figsize=(12,6))

# %%
df.plot(kind= 'scatter',
       x = 'HARDSHIP INDEX',
       y= 'PER CAPITA INCOME ',
       color= 'black',
       figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='HARDSHIP INDEX', ylabel='PER CAPITA INCOME '>

# %%
census = pd.read_csv('/Users/asanchez/Downloads/Census2020SupplementCCA.csv')
census
# Out:
#     GEOID                GEOG  TOT_POP  POP_HH  POP_GQ   HISP  WHITE  BLACK  \
# 0       1         Rogers Park    55628   52242    3386  12587  22292  13819
# 1       2          West Ridge    77122   75531    1591  15307  28212  10484
# 2       3              Uptown    57182   55082    2100   7587  29871  10800
# 3       4      Lincoln Square    40494   39969     525   7069  25342   1601
# 4       5        North Center    35114   35058      56   4503  25799    780
# ..    ...                 ...      ...     ...     ...    ...    ...    ...
# 72     73  Washington Heights    25065   24901     164    544     95  23849
# 73     74     Mount Greenwood    18628   18280     348   1994  15256    753
# 74     75         Morgan Park    21186   20636     550    964   5838  13649
# 75     76              O'Hare    13418   13407      11   1492   9174    385
# 76     77           Edgewater    56296   53265    3031   8466  30962   6820
#
#     ASIAN  OTHER  HU_TOT  TOT_HH  VAC_HU   HH_SIZE
# ...

# %%
census.head(50).plot(kind= 'bar',
       x = 'GEOG',
       y= 'HISP')
# Out:
# <AxesSubplot:xlabel='GEOG'>

# %%
hispanic = pd.read_csv('/Users/asanchez/Downloads/Pop_Hispanic .csv')
hispanic
# Out:
#     GEOID             GEOG  TOT_POP  POP_HH  POP_GQ   HISP  WHITE  BLACK  \
# 0      19   Belmont Cragin    78116   77901     215  63967   8867   2633
# 1      30   South Lawndale    71399   66262    5137  61970   2328   6246
# 2      58    Brighton Park    45053   45038      15  36756   2474    591
# 3      63        Gage Park    39540   39508      32  36132   1393   1398
# 4      66     Chicago Lawn    55931   55904      27  32949   1571  20443
# ..    ...              ...      ...     ...     ...    ...    ...    ...
# 72     40  Washington Park    12707   12647      60    380    110  11924
# 73     54        Riverdale     7262    7248      14    206     41   6830
# 74     36          Oakland     6799    6799       0    204    179   6149
# 75     45      Avalon Park     9458    9457       1    193     46   8922
# 76     47         Burnside     2527    2527       0     65      4   2386
#
#     ASIAN  OTHER  HU_TOT  TOT_HH  VAC_HU   HH_SIZE
# ...

# %%
hispanic.head(15).plot(kind= 'bar',
       x = 'GEOG',
       y= 'HISP',
                      color= "green")
# Out:
# <AxesSubplot:xlabel='GEOG'>

# %%
hardship = pd.read_csv('/Users/asanchez/Downloads/Neigh_Hardship.csv')
hardship
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                      14         Albany Park                        11.3
# 1                      15        Portage Park                         4.1
# 2                      16         Irving Park                         6.3
# 3                      19      Belmont Cragin                        10.8
# 4                      20             Hermosa                         6.9
# 5                      22        Logan Square                         3.2
# 6                      23       Humboldt park                        14.8
# 7                      30      South Lawndale                        15.2
# 8                      31     Lower West Side                         9.6
# 9                      58       Brighton Park                        14.4
# 10                     61            New City                        11.9
# 11                     63           Gage Park                        15.8
# ...

# %%
hardship.head(15).plot(kind= 'bar',
       x = 'COMMUNITY AREA NAME',
       y= 'HARDSHIP INDEX',
                      color= "red")
# Out:
# <AxesSubplot:xlabel='COMMUNITY AREA NAME'>

# %%
crime = pd.read_csv('/Users/asanchez/Downloads/Crime_Pilsen.csv')
crime
# Out:
#      CASE_NUMBER           DATE                   BLOCK VICTIMIZATION_PRIMARY  \
# 0        A352470   5/26/96 3:45       2200 S PAULINA ST              HOMICIDE
# 1        A395011   6/5/96 20:20     1600 S NEWBERRY AVE              HOMICIDE
# 2        A529369  7/27/96 11:20  2500 S BLUE ISLAND AVE              HOMICIDE
# 3        A612354  8/20/96 15:40          1100 W 19TH PL              HOMICIDE
# 4        A627618  8/26/96 20:30           1800 S MAY ST              HOMICIDE
# ...          ...            ...                     ...                   ...
# 1529         NaN            NaN                     NaN                   NaN
# 1530         NaN            NaN                     NaN                   NaN
# 1531         NaN            NaN                     NaN                   NaN
# 1532         NaN            NaN                     NaN                   NaN
# 1533         NaN            NaN                     NaN                   NaN
#
# ...
